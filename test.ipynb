# %%
import re
prompt ='cake'
prompt = re.sub(r'\$\$', prompt, '$$in dark night')
prompt
# Out:
# 'cakein dark night'

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
import matplotlib.pyplot as plt
import numpy as np

# Initialize k
k = 1

# Create a button
button = widgets.Button(description="Show Image")

# Create a figure and axis
fig, ax = plt.subplots()

# Create initial image
image_data = np.random.rand(100, 100)

ax.axis('off')

# Create a function to update the image
def update_image(button):
    global k, image_data  # Access the global variables
    # Clear previous output
    clear_output(wait=True)
    
    # Update image data
    image_data = np.random.rand(100, 100)
    
    # Update the image in the plot
    image_plot = ax.imshow(image_data, cmap='gray')
    
    # Refresh the plot
    plt.draw()

# Attach the function to the button's click event
button.on_click(update_image)

# Display the button
display(button)
# Out:
# Button(description='Show Image', style=ButtonStyle())
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
while True:
    pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 while True:
# ----> 2     pass
#
# KeyboardInterrupt:
